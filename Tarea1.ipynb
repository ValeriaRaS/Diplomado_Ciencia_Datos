# %% [markdown]
# <a href="https://colab.research.google.com/github/ValeriaRaS/Diplomado_Ciencia_datos/blob/main/Tarea1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.1 PROMEDIO MATEMÁTICO

# %% [markdown]
# ## 1.2 Logo

# %% [markdown]
# ![pythonl.png](data:image/png;base64,...)

# %%
import cv2
import matplotlib.pyplot as plt
path = "/content/pythonl (1).png"
img = cv2.imread(path)
im_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(im_rgb)

# %%
# !pwd
# Out:
# /content

# %%
from google.colab import files
from IPython.display import Image

uploaded= files.upload()
# Out:
#      <input type="file" id="files-86d3f9af-bc6f-40b6-bf95-a42613ecc699" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-86d3f9af-bc6f-40b6-bf95-a42613ecc699">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image("pythonl.png", width= 100)

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
testImg=cv2.imread("/content/pythonl (1).png")
cv2_imshow(testImg)
# Out:
# <PIL.Image.Image image mode=RGB size=1869x2048 at 0x7FDB527A4D30>

# %% [markdown]
# ## 1.3 Presentación de la Autora

# %%
from google.colab import files
from IPython.display import Image

uploaded= files.upload()
# Out:
#      <input type="file" id="files-ceba2783-3aaf-4e8a-8968-b59685dc4380" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ceba2783-3aaf-4e8a-8968-b59685dc4380">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
Image("IMG-20171205-WA0002 (2).jpg", width= 500)

# %% [markdown]
# Mi nombre es Valeria Ramírez Sánchez, tengo 23 años y soy estudiante de la carrera de Estadística de la Universidad Nacional de Colombia, sede Bogotá. Estoy en mi último semestre realizando prácticas en el Banco de la República en el departamente de inflación y prgramación. Espero aprender muchisimo y asi cumplir el objetivo de graduarme como estadística este año.

# %% [markdown]
# ## 1.4 ¿Qué es el promedio matematico o media?

# %% [markdown]
# El promedio es un valor "central" calculado entre un conjunto de números. Es un número representativo que puede obtenerse a partir de una lista de cifras. Usualmente se relaciona con el concepto de media aritmética.
#
# Es fácil de calcular: suma todos los números y divide por la cantidad de números que hay, y se obtiene el promedio.
#
#  Promedio = $\bar{x}$ = $\frac{x_1 + x_2 + ... + x_n}{ n}$

# %% [markdown]
# ### Ejemplo: Promedio de 3, 7, 15 y 10

# %%
Promedio =  (3+7+15+10)/4
Promedio
# Out:
# 8.75

# %% [markdown]
# ## 1.5 Referencias
#
# 1. Promedio. (s/f). Disfrutalasmatematicas.com. Recuperado el 14 de febrero de 2023, de https://www.disfrutalasmatematicas.com/definiciones/promedio.html
#
#
# 2. Westreicher, G. (2021, enero 27). Promedio. Economipedia. https://economipedia.com/definiciones/promedio.html

# %% [markdown]
# Par ver en Colb ingresa a
# https://colab.research.google.com/drive/1K4krdFA-obP4duTH4Gx7sDw_jYfrrSGb?usp=sharing

# %%
[]
